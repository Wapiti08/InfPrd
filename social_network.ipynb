# %% [markdown]
# <a href="https://colab.research.google.com/github/Wapiti08/InfPrd/blob/main/social_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx

# %%
G = nx.read_edgelist("facebook_combined.txt", create_using=nx.Graph(), nodetype=int)

# %%
nx.info(G)
# Out:
# 'Graph with 4039 nodes and 88234 edges'

# %%
# nx.draw(G, edge_color='b', node_color='r')
import matplotlib.pyplot as plt
plt.figure(figsize=(18,18))
nx.draw_networkx(G, pos=nx.spring_layout(G), with_labels=False, node_size=35)
plt.show()

# %%
nx.degree_pearson_correlation_coefficient(G)
# Out:
# 0.06357722918564912

# %%
# draw metric

def draw_metric(G, dct, layout):
  top = 10
  dct = sorted(dct, key=lambda item: item[1], reverse=True)[: top]
  # get the key list
  key_list = [key for (key, value) in dct]
  # get the value list
  value_list = [value for (key, value) in dct]
  plt.show("off")
  # draw the graphs
  nx.draw_networkx(G, cmap='Blue')
  # draw the node
  nx.draw_networkx_nodes(G,
                         n)

# %%
dct = nx.degree(G)
layout = nx.spring_layout(G)
draw_metric(G, dct, layout)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-dc491fdee197> in <module>()
#       1 dct = nx.degree(G)
#       2 layout = nx.spring_layout(G)
# ----> 3 draw_metric(G, dct, layout)
#
# <ipython-input-11-c727ef4e9359> in draw_metric(G, dct, layout)
#      13   # draw the node
#      14   nx.draw_networkx_nodes(G,
# ---> 15                          node_list=key_list)
#
# TypeError: draw_networkx_nodes() got an unexpected keyword argument 'node_list'
